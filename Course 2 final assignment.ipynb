# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Name: **JASMEET SINGH** <br>
# Desired Occupation: Data Analyst

# %% [markdown]
# *I am interested in data science because data ammuses me, how just a bunch of people with past records, right set of tools, and skills can give us a meaningful insight about what the possible future of an orgnization looks like, and help the organization to take the best course of action. Working with data will never be monotonous as every new dataset comes with a new set of challenges moreover Every moment we spend on the internet, more and more data is being generated and the field is evolving and I would love to be a part of it someday.*

# %% [markdown]
# ### Code below takes radius of a sphere as an input and returns it's volume as an output:

# %%
import math

# %%
r=int(input("Enter the radius of the sphere to calculate it's volume: "))
print(f'Volume of sphere of radius {r} is {(4/3)*math.pi*(r**3)}')
# Out:
# Enter the radius of the sphere to calculate it's volume: 2
# Volume of sphere of radius 2 is 33.510321638291124

# %% [markdown]
# Strikethrough: ~~3 Important Languages for Data Science:~~
#
# Numbered and Bullet lists:
# <ol>
# <li>Python:
#     <ul>
#         <li>High Level General purpose programming language.</li>
#     </ul>
#     </li>
#     <li>R:
#         <ul>
#             <li>Free software.</li>
#             <li>Has array-oriented format.</li>
#         </ul>
#     </li>
#     <li>SQL:
#         <ul>
#             <li>Used for querrying and managing data.</li>
#         </ul>
#     </li>
# </ol>
#
#
#
# Block code:
# ```Python
# str = "This is block level code"
# print(str)
#
#
# ```
#
# Blockquote:
# Output of the above code should be:
# <blockquote>This is block level code</blockquote>
#
# Tables:
#
# <h3 align="center">Dataset</h3>
#
# |Name|Address|Salary|
# |-----|-------|------|
# |Michael|Brisban|4000|
# |Steve|Sydney|5000|
#
# Image and Hyperlink: <br>
# Here is an image i found: <br>
# [click here to open this Image in a new tab](https://thumbs.dreamstime.com/z/big-data-science-analysis-business-technology-concept-virtual-screen-big-data-science-analysis-business-technology-concept-145015243.jpg)
# ![big-data-science-analysis-business-technology-concept-virtual-screen-big-data-science-analysis-business-technology-concept-145015243.jpg](attachment:big-data-science-analysis-business-technology-concept-virtual-screen-big-data-science-analysis-business-technology-concept-145015243.jpg)
